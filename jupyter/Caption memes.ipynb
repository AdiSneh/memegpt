# %%
import json
import requests

from pathlib import Path

# %%
MEMES_PATH = Path('src/memegpt/memes.json')
USERNAME = 'memegpt'
PASSWORD = ''

# %%
with open(MEMES_PATH) as f:
    memes = json.load(f)

# %%
data = {
    'template_id': 180190441,
    'username': USERNAME,
    'password': PASSWORD,
#     text0='text0',
#     text1='text1',
#     text2='text2',
    'boxes[0][text]': 'text 0',
    '&boxes[0][x]': 150,
    '&boxes[0][y]': 107,
    '&boxes[0][w]': 451,
    '&boxes[0][h]': 381,
    '&boxes[0][color]': '#ff0000',
    'boxes[1][text]': 'text 1',
    '&boxes[1][x]': 797,
    '&boxes[1][y]': 193,
    '&boxes[1][w]': 539,
    '&boxes[1][h]': 389,
    '&boxes[1][color]': '#000000',
    'boxes[2][text]': 'text 2',
    '&boxes[2][x]': 484,
    '&boxes[2][y]': 1239,
    '&boxes[2][w]': 823,
    '&boxes[2][h]': 177,
    '&boxes[2][color]': '#000000',
}

# %%
params = {
    "template_id": 181913649,
    'username': USERNAME,
    'password': PASSWORD,
    "boxes[0][text]": "top",
    "boxes[1][text]": "bottom",
}

# %%
response = requests.post(
    'https://api.imgflip.com/caption_image',
    data=params,
)
response.json()
# Out:
# {'success': True,
#  'data': {'url': 'https://i.imgflip.com/7dfqcs.jpg',
#   'page_url': 'https://imgflip.com/i/7dfqcs'}}

# %%
memes
# Out:
# {'memes': [{'id': 181913649,
#    'uid': 27,
#    'name': 'Drake Hotline Bling',
#    'w': 1200,
#    'h': 1200,
#    'file_type': 'jpg',
#    'url_name': 'Drake-Hotline-Bling',
#    'altNames': 'drakeposting, drakepost, drake hotline approves, drake no yes, drake like dislike, drake faces',
#    'safe_for_work': 'yes',
#    'default_settings': '[{"type":"text","x":612.2448979591837,"y":12.244897959183673,"w":575.5102040816327,"h":575.5102040816327,"rotation":0,"font":"arial","font_color":"#000000","outline_color":"#ffffff","force_caps":false,"text_align":"center","vertical_align":"middle"},{"type":"text","x":612.2448979591837,"y":612.2448979591837,"w":575.5102040816327,"h":575.5102040816327,"rotation":0,"font":"arial","font_color":"#000000","outline_color":"#ffffff","force_caps":false,"text_align":"center","vertical_align":"middle"}]',
#    'has_transparency': 0},
#   {'id': 87743020,
#    'uid': 0,
#    'name': 'Two Buttons',
#    'w': 600,
#    'h': 908,
#    'file_type': 'jpg',
# ...
